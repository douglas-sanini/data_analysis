# %% [markdown]
# In this exercise we create a code that generates interpolated values for a function. In this case we have done this for a gaussian distribution.

# %%
import scipy as sp
import numpy as np
from numpy import array
import matplotlib.pyplot as plt
from random import uniform
import functions.functions as fs

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 16, 8
    
mu = 0
sigma = 1

_x = np.linspace(-5,5,500)

#getting values for gaussion distribution:
_y = fs.gaussian_dist(_x,mu,sigma)



#plotting gaussian function
plt.plot(_x, _y, c = 'r')


x = np.linspace(-5,5,50)
y = fs.gaussian_dist(x,mu,sigma)

#plotting points before linear interpolation
plt.bar(x, y, alpha = 0.3)
# Out:
# <BarContainer object of 50 artists>

# %%
#this sorts in order original values of x with new values of x for interpolated values
all_x = fs.x_values(x)

#this gives us interpolated values and put it in order with the original distribution values
all_y = fs.interpolated_and_other(x, y)


#Now we can finally plot all oringal and interpolated values after interpolation
plt.plot(_x, _y, c = 'r')
plt.bar(all_x, all_y, alpha = 0.3)
# Out:
# <BarContainer object of 99 artists>
